# %% [markdown]
# # `beautifulSoup` 套件介紹

# %%
# !pipenv install beautifulsoup4
# !pipenv install html5lib
# !pipenv install lxml

# %% [markdown]
# ## 使用`requests`獲得網頁，並且使用`bs`來技取傳回資料的內容

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.must.edu.tw/'
#發送 GET 請求到 url，並將回應物件放到 resp
resp = requests.get(url)
# 將 resp.text 也就是 HTML 資料定義到 BeautifulSoup 物件內，並用 html5lib 解析 HTML 內容
soup = BeautifulSoup(resp.text, 'lxml')

# 輸出網頁的 title
print(soup.title.getText())

#輸出第一個尋找到的 <li> 元素的文字
print('li1')
print(soup.li.getText())

#輸出第一個尋找到的 <li> 元素的文字(相同效果)
print('li2')
print(soup.find('li').getText())

#尋找全部 <li> 元素的文字
lst = soup.find_all('li')
for li in lst:
    print(li.getText())

# %% [markdown]
# ## 取得標籤屬性
# 若想在一個標籤內取得該標籤的屬性，只需像字典一樣操作即可。
#
# 例如有個標籤為 `<a href='https://www.google.com'>OwO</a>`，`soup.a['href']` 即可取得該標籤的屬性`https://www.google.com`

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.must.edu.tw/'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html5lib')

links = soup.find_all('a')
for link in links:
    if 'href' in link.attrs:
        print(link['href'])

# %% [markdown]
# ## BeautifulSoup 定位
# * `soup.find()` : 根據條件回傳"第一個"符合的元素，由字串表示，若沒有符合的則回傳 None。
# * `soup.find_all()` : 根據條件回傳"全部"符合的元素，由串列表示，若沒有符合的則回傳空串列。
# * `soup.select()` : Css Selector。
#
# 可以透過標籤、 `id` 或 `class`來定位元素， `soup.find('p', id='myid', class_='myclass')` ，注意 class 後方必須加上底線，為了避免與 Python 的關鍵字`class`衝突。

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.ptt.cc/bbs/Beauty/index.html"
res = requests.get(url,cookies = {'over18':'1'}) 
#記得八卦版要over18=1這個cookies！
Soup = BeautifulSoup(res.text,'lxml') 
print(Soup.title) #可以讀取的網頁的title
print(Soup.title.text) 
Soup.find(class_='r-ent') #我們就可以找到第一個class為'r-ent'的元素了
Soup.find(class_='r-ent').find(class_='title') 
Soup.find(class_='r-ent').find(class_='title').find('a')
Soup.find_all(class_='r-ent')

# %% [markdown]
# ## CSS Selector

# %%
# CSS Selector

Soup.select_one('.r-ent > .title > a ')
for i in Soup.select('.r-ent > .title > a '):
    print(i.text) #印出標題
    print('https://www.ptt.cc',end='') #補上不完整的網址
    print(i['href']) #讀出藏在href中的超連結網址

# %%
import requests
from bs4 import BeautifulSoup
homepage = requests.get('https://www.ptt.cc/bbs/hotboards.html')

soup = BeautifulSoup(homepage.text,'lxml')
board_find = soup.find_all('a', class_= 'board')
board_select = soup.select_one('a.board')
for i in board_find:
    print(i.text)
# Out:
# Gossiping
# 12829
# 綜合
# ◎[八卦] 黃牛法實名制是佛地魔嗎？
#
#
# Baseball
# 9755
# 棒球
# ◎[棒球] 吳念庭先發2棒出戰羅德
#
#
# C_Chat
# 4249
# 閒談
# ◎[希恰] 本屆的勝負：早坂愛的勝利
#
#
# Stock
# 4227
# 學術
# ◎[股票] 台積電四月營收 mom+1.7%
#
#
# Elephants
# 3577
# CPBL
# ◎[兄弟] 助下恰上大震撼
#
#
# NBA
# 2953
# NBA.
# ◎[NBA] 新任板主熱烈募集中!!!
#
#
# LoL
# 1933
# 遊戲
# ◎[LoL] 2023 季中邀請賽淘汰賽階段
#
#
# Lifeismoney
# 1459
# 省錢
# ◎[省錢] 省錢板 發文要有省錢點
#
#
# KoreaStar
# 1096
# 韓國
# ◎[韓星] 史哲，實名制是佛地魔嗎？
#
#
# BaseballXXXX
# 1052
# ４Ｘ
# ◎[ 4X ] 歡迎Josh大駕光臨
#
#
# home-sale
# 962
# 房屋
# ◎[房屋] 禁無關看板新聞/租賃廣告
#
#
# BabyMother
# 845
# 家庭
# ◎[寶媽] 天氣多變化 多準備衣物
#
#
# HatePolitics
# 823
# Hate
# ◎[政黑] 進板圖 徵至 05/22
#
#
# car
# 750
# 車車
# ◎[汽車] 大家要注意板規1-8喔
#
#
# Tech_Job
# 696
# 工作
# ◎[科技] 版規三政治水桶恢復至7天
#
#
# movie
# 656
# 綜合
# ◎[電影] 請注意防雷/分類/電影點
#
#
# sex
# 655
# 男女
# ◎[西斯]
#
#
# MobileComm
# 639
# 資訊
# ◎[通訊] 手機情報o資費比較o交易x
#
#
# Beauty
# 610
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
#
#
# Military
# 579
# 軍事
# ◎[軍事] 誠徵 Military 板板主
#
#
# PC_Shopping
# 567
# 硬體
# ◎[電蝦]TWZLR50294/TWACR50160華碩
#
#
# basketballTW
# 499
# 籃球
# ◎[台籃] 季後賽
#
#
# Japan_Travel
# 487
# 旅遊
# ◎發問前請注意是否有事先查過資訊
#
#
# SportLottery
# 456
# 博弈
# ◎[運彩] 量力而為 樂趣加倍
#
#
# creditcard
# 412
# 理財
# ◎[卡板] 禁發花旗揪團團主宣傳文章
#
#
# TaichungBun
# 409
# 台中
# ◎[台中] 節約用水
#
#
# WomenTalk
# 350
# 聊天
# ◎[女孩]女板板主徵選<（＠ｏ＠）／
#
#
# japanavgirls
# 349
# 綜合
# ◎AV女優板 清新、優質,神人照格式
#
#
# Tainan
# 346
# 台南
# ◎[台南] 地震頻繁!請鄉親注意安全
#
#
# NSwitch
# 322
# 主機
# ◎[NS] 薩爾達傳說 王國之淚 5/12
#
#
# Steam
# 294
# 平台
# ◎本板禁止買賣合購代購代刷
#
#
# AllTogether
# 288
# 聯誼
# ◎[歐兔] (╭￣3￣)╭♡～～♥～♥
#
#
# KoreaDrama
# 257
# 韓劇
# ◎[韓劇]
#
#
# Kaohsiung
# 253
# 高雄
# ◎[高雄]~喵嗨囉~歡迎來到高雄版捏~
#
#
# Japandrama
# 251
# 日劇
# ◎[日劇] 金22 目黑蓮
#
#
# Boy-Girl
# 250
# 心情
# ◎[男女] 板主選舉報名至5月11日 !
#
#
# China-Drama
# 249
# 中劇
# ◎[中劇] 片單好多劇，看不完啊！
#
#
# Marginalman
# 229
# 心情
# ◎[邊緣] 板主投票開始囉
#
#
# Aviation
# 222
# 交通
# ◎[航空] 航空板 請先詳閱板規
#
#
# e-shopping
# 220
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
#
#
# iOS
# 216
# 系統
# ◎[iOS] WWDC23：6/6~6/10 (online)
#
#
# marriage
# 209
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
#
#
# BeautySalon
# 188
# 美容
# ◎[美保] 2/20起跟口罩悶痘道別
#
#
# marvel
# 178
# 生二
# ◎[媽佛] 看marvel四周就不熱了喔!!
#
#
# Brand
# 174
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
#
#
# CVS
# 174
# 資訊
# ◎[CVS] 沙漠綠洲-便利商店
#
#
# CFantasy
# 173
# 玄幻
# ◎[玄幻] 玄幻小說板 板規3.0出爐
#
#
# HardwareSale
# 171
# 買賣
# ◎[硬交] 販售文請附實體照
#
#
# DIABLO
# 166
# 線上
# ◎[暗黑] 5/13~5/15 D4壓力測試!
#
#
# Lakers
# 164
# W-PA
# ◎[Lakers] 5/11 10點 Game5 @勇士
#
#
# joke
# 157
# 娛樂
# ◎[就可]
#
#
# PlayStation
# 156
# 主機
# ◎[PS5] 4/28 星際大戰 絕地:倖存者
#
#
# AC_In
# 149
# 閒談
# ◎[裏洽] 勤洗手
#
#
# ONE_PIECE
# 145
# 日本
# ◎[海賊王] 1083 那天的真相扉頁
#
#
# studyteacher
# 143
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
#
#
# biker
# 141
# 車車
# ◎[機車]看板活動進行中
#
#
# CarShop
# 138
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
#
#
# miHoYo
# 133
# 米哈
# ◎[米哈遊] 原神長草期
#
#
# Gamesale
# 129
# 綜合
# ◎[GS] 遊戲交易板
#
#
# KR_Entertain
# 128
# 綜藝
# ◎[韓綜] Show Me The 新板主!
#
#
# MRT
# 120
# 交通
# ◎[捷運] 中捷被砸 建商麥造
#
#
# watch
# 116
# 購一
# ◎[錶板] Show me your Watch!
#
#
# PuzzleDragon
# 115
# 轉珠
# ◎[P＆D] 假面騎士 合作復刻
#
#
# KoreanPop
# 115
# 音樂
# ◎抵制買榜 抵制作弊，韓樂需要正義
#
#
# Soft_Job
# 111
# 工作
# ◎[軟工] 新年快樂
#
#
# WOW
# 111
# 線上
# ◎[WoW] 巨龍來了 - 徵版主
#
#
# TaiwanDrama
# 111
# 臺劇
# ◎[臺劇] 最佳利益：決戰利益 S2
#
#
# MakeUp
# 111
# 美容
# ◎[美妝] 2/20起唇彩口紅拿出來
#
#
# YuanChuang
# 110
# 原創
# ◎[原創] 年度必看徵文 進行中!
#
#
# Headphone
# 105
# 資訊
# ◎Dopin R.I.P 我們永遠懷念你
#
#
# EAseries
# 105
# 歐美
# ◎[EA] 歐美影集版
#
#
# Hsinchu
# 102
# 新竹
# ◎[新竹] 贈送文7天一篇
#
#
# DigiCurrency
# 102
# 資訊
# ◎[數位貨幣] Sorry, bank run
#
#
# Hip-Hop
# 102
# 音樂
# ◎[嘻哈]
#
#
# Drama-Ticket
# 101
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
#
#
# FATE_GO
# 100
# 手遊
# ◎[FGO] 台 六周年關卡 回憶過去
#
#
# ToS
# 99
# 轉珠
# ◎[神魔] 火礫山的熊熊烈火
#
#
# Monkeys
# 99
# CPBL
# ◎樂天桃猿！文智停車場開放到5/7
#
#
# MacShop
# 98
# 資訊
# ◎增設 臨時板規 20220916 詳見置底
#
#
# mobilesales
# 91
# 資訊
# ◎[Mobile] 板規不看，水桶就來
#
#
# Salary
# 89
# 職場
# ◎[職場] 工作職場板
#
#
# DSLR
# 87
# 攝影
# ◎[攝影] 2023
#
#
# Bank_Service
# 86
# 銀行
# ◎[銀行服務板] 高利率數位帳戶置底
#
#
# StupidClown
# 86
# 經歷
# ◎ 哼哼哼哼
#
#
# cat
# 85
# 寵物
# ◎喵板～
#
#
# E-appliance
# 83
# 資訊
# ◎[家電] 發文請照規定發文
#
#
# Food
# 83
# 美食
# ◎美食板
#
#
# Lions
# 82
# CPBL
# ◎2023 中職34年球季開打
#
#
# Gov_owned
# 78
# 國營
# ◎[國營] 徵求上榜心得文
#
#
# BabyProducts
# 77
# 買賣
# ◎歡迎置底分享2023二手市集活動
#
#
# MuscleBeach
# 73
# 美體
# ◎[健身] 發文前請務必詳閱板規
#
#
# SakaTalk
# 71
# 日本
# ◎坂道閒聊板
#
#
# Wanted
# 68
# 徵求
# ◎[汪踢] 這裡是汪踢板
#
#
# DC_SALE
# 66
# 攝影
# ◎數位相機交易 - 注意詐騙
#
#
# Option
# 65
# 學術
# ◎[期權] 手續費洽broker板
#
#
# PokemonGO
# 65
# 抓寶
# ◎[PMGO] 5/13龍柱菁英戰5/14對戰日
#
#
# Hearthstone
# 64
# 線上
# ◎[爐石] 《傳說音樂祭》
#
#
# G-S-WARRIORS
# 63
# W-PA
# ◎西二輪G5，05/11_10:00，vs 湖人
#
#
# MayDay
# 63
# 臺灣
# ◎五月天
#
#
# MLB
# 63
# #MLB
# ◎2023 球季正式開始
#
#
# TW_Entertain
# 62
# 綜藝
# ◎[台綜] 哈囉！毛小孩 週六晚8台視
#
#
# give
# 61
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
#
#
# Guardians
# 61
# CPBL
# ◎[悍將] 陳宛晶新聞須加註
#
#
# Audiophile
# 60
# 資訊
# ◎[喇音] 請詳閱置底交易文新板規
#
#
# SuperBike
# 59
# 車車
# ◎PTT重機板 ~ 發買賣文請詳閱置底
#
#
# Coffee
# 58
# 咖啡
# ◎咖啡 秋意漸濃
#
#
# PublicServan
# 57
# 公職
# ◎[公職]
#
#
# fastfood
# 57
# 美食
# ◎[速食] 慟！甜心卡已死
#
#
# Finance
# 55
# 金融
# ◎國泰世華銀行副總 鄧崇儀
#
#
# nb-shopping
# 55
# 硬體
# ◎[筆電蝦]
#
#
# Key_Mou_Pad
# 55
# 生活
# ◎[鍵鼠] 兔年行大運
#
#
# Tennis
# 52
# 網球
# ◎[網球] AO - Djokovic & Sabalenka
#
#
# Teacher
# 51
# 教師
# ◎[踢雀] 晚春四月~~
#
#
# e-coupon
# 51
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
#
#
# Korea_Travel
# 50
# 旅遊
# ◎韓國旅遊板(韓幣交易桶10年)
#
#
# BlueArchive
# 49
# 蔚藍
# ◎[蔚藍] 女僕兔女郎
#
#
# UmaMusume
# 46
# 賽馬
# ◎[馬娘] ☆3大穴/NTR: /小萌使用(
#
#
# facelift
# 46
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
#
#
# lesbian
# 45
# 男女
# ◎[拉板] 板主投票開始~請按大V投票
#
#
# MobilePay
# 43
# 理財
# ◎刷卡回饋問題請至信用卡板
#
#
# CN_Entertain
# 43
# 綜藝
# ◎[中綜] 乘風2023
#
#
# part-time
# 42
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
#
#
# DMM_GAMES
# 42
# 遊戲
# ◎[DMMG] VISA真的能用
#
#
# SET
# 41
# 頻道
# ◎[泣]我立刻爆炸 我立刻要斷你龍脈
#
#
# FAPL
# 41
# 聯賽
# ◎歡樂．三喵．足球
#
#
# gay
# 41
# 男女
# ◎[甲板]天氣變化大注意身體健康
#
#
# Vtuber
# 39
# 偶像
# ◎[Vtub] VSPO開始分批3D披露
#
#
# HelpBuy
# 39
# 買賣
# ◎[代買] 貼文請先看板規及置底公告

# %% [markdown]
# ## 測試不同parser的速度

# %%
import requests
from bs4 import BeautifulSoup
import time
start = time.time()
homepage = requests.get('https://www.ptt.cc/bbs/hotboards.html')
# print(homepage.text)
a = 0
b = 0
c = 0
d = 0
for i in range(1,100):
    with open ('nosoup.text','a', encoding="utf-8") as f:
        f.write(homepage.text)
    end = time.time()
    elapsed = end - start
    a = a + elapsed
    print("Time taken nosoup: ", elapsed, "seconds.")

    start = time.time()
    soup = BeautifulSoup(homepage.text,'lxml')
    # print(soup)
    with open ('lxml.text','a', encoding="utf-8") as f:
        f.write(soup.text)
    end = time.time()
    elapsed = end - start
    b = b + elapsed
    print("Time taken lxml.text: ", elapsed, "seconds.")    

    start = time.time()
    h5soup = BeautifulSoup(homepage.text,'html5lib')
    # print(h5soup)
    with open ('html5lib.text','a', encoding="utf-8") as f:
        f.write(h5soup.text)
    end = time.time()
    elapsed = end - start
    c = c + elapsed
    print("Time taken html5lib: ", elapsed, "seconds.")    

    start = time.time()    
    pasersoup = BeautifulSoup(homepage.text,'html.parser')
    # print(pasersoup)
    with open ('htmlparser.text','a', encoding="utf-8") as f:
        f.write(pasersoup.text)

    end = time.time()
    elapsed = end - start
    d = d + elapsed
    print("Time taken htmlparser: ", elapsed, "seconds.")

print("Time taken nosoup: ", a, "seconds.")
print("Time taken lxml: ", b, "seconds.")
print("Time taken html5lib: ", c, "seconds.")
print("Time taken htmlparser: ", d, "seconds.")
# Out:
# Time taken nosoup:  0.58732008934021 seconds.
# Time taken lxml.text:  0.04574775695800781 seconds.
# Time taken html5lib:  0.2320704460144043 seconds.
# Time taken htmlparser:  0.041170358657836914 seconds.
# Time taken nosoup:  0.041170358657836914 seconds.
# Time taken lxml.text:  0.028324365615844727 seconds.
# Time taken html5lib:  0.06614828109741211 seconds.
# Time taken htmlparser:  0.04533219337463379 seconds.
# Time taken nosoup:  0.05366253852844238 seconds.
# Time taken lxml.text:  0.027497291564941406 seconds.
# Time taken html5lib:  0.06992125511169434 seconds.
# Time taken htmlparser:  0.09487366676330566 seconds.
# Time taken nosoup:  0.11673712730407715 seconds.
# Time taken lxml.text:  0.03943443298339844 seconds.
# Time taken html5lib:  0.13004279136657715 seconds.
# Time taken htmlparser:  0.04869651794433594 seconds.
# Time taken nosoup:  0.0509028434753418 seconds.
# Time taken lxml.text:  0.031079530715942383 seconds.
# Time taken html5lib:  0.054123640060424805 seconds.
# Time taken htmlparser:  0.12564611434936523 seconds.
# Time taken nosoup:  0.12564611434936523 seconds.
# Time taken lxml.text:  0.4879794120788574 seconds.
# Time taken html5lib:  0.10595583915710449 seconds.
# Time taken htmlparser:  0.04699850082397461 seconds.
# Time taken nosoup:  0.04802250862121582 seconds.
# Time taken lxml.text:  0.026816606521606445 seconds.
# Time taken html5lib:  0.14370107650756836 seconds.
# Time taken htmlparser:  0.03751540184020996 seconds.
# Time taken nosoup:  0.0388338565826416 seconds.
# Time taken lxml.text:  0.027039051055908203 seconds.
# Time taken html5lib:  0.12015819549560547 seconds.
# Time taken htmlparser:  0.05075693130493164 seconds.
# Time taken nosoup:  0.0515589714050293 seconds.
# Time taken lxml.text:  0.03830385208129883 seconds.
# Time taken html5lib:  0.09849691390991211 seconds.
# Time taken htmlparser:  0.023863554000854492 seconds.
# Time taken nosoup:  0.023863554000854492 seconds.
# Time taken lxml.text:  0.0 seconds.
# Time taken html5lib:  0.1813654899597168 seconds.
# Time taken htmlparser:  0.0064814090728759766 seconds.
# Time taken nosoup:  0.0064814090728759766 seconds.
# Time taken lxml.text:  0.04788637161254883 seconds.
# Time taken html5lib:  0.1966700553894043 seconds.
# Time taken htmlparser:  0.10906362533569336 seconds.
# Time taken nosoup:  0.10906362533569336 seconds.
# Time taken lxml.text:  0.03506827354431152 seconds.
# Time taken html5lib:  0.09197473526000977 seconds.
# Time taken htmlparser:  0.06477975845336914 seconds.
# Time taken nosoup:  0.08488011360168457 seconds.
# Time taken lxml.text:  0.030902862548828125 seconds.
# Time taken html5lib:  0.08073878288269043 seconds.
# Time taken htmlparser:  0.0672464370727539 seconds.
# Time taken nosoup:  0.0672464370727539 seconds.
# Time taken lxml.text:  0.07133769989013672 seconds.
# Time taken html5lib:  0.11733293533325195 seconds.
# Time taken htmlparser:  0.017985820770263672 seconds.
# Time taken nosoup:  0.017985820770263672 seconds.
# Time taken lxml.text:  0.1268017292022705 seconds.
# Time taken html5lib:  0.08449792861938477 seconds.
# Time taken htmlparser:  0.03843069076538086 seconds.
# Time taken nosoup:  0.0401155948638916 seconds.
# Time taken lxml.text:  0.09925508499145508 seconds.
# Time taken html5lib:  0.04191470146179199 seconds.
# Time taken htmlparser:  0.09400200843811035 seconds.
# Time taken nosoup:  0.09483814239501953 seconds.
# Time taken lxml.text:  0.03228902816772461 seconds.
# Time taken html5lib:  0.061483144760131836 seconds.
# Time taken htmlparser:  0.023299455642700195 seconds.
# Time taken nosoup:  0.05423331260681152 seconds.
# Time taken lxml.text:  0.02797722816467285 seconds.
# Time taken html5lib:  0.1400458812713623 seconds.
# Time taken htmlparser:  0.06901884078979492 seconds.
# Time taken nosoup:  0.06901884078979492 seconds.
# Time taken lxml.text:  0.1100308895111084 seconds.
# Time taken html5lib:  0.10222864151000977 seconds.
# Time taken htmlparser:  0.03515505790710449 seconds.
# Time taken nosoup:  0.03515505790710449 seconds.
# Time taken lxml.text:  0.03772234916687012 seconds.
# Time taken html5lib:  0.07249212265014648 seconds.
# Time taken htmlparser:  0.1783897876739502 seconds.
# Time taken nosoup:  0.1783897876739502 seconds.
# Time taken lxml.text:  0.026232004165649414 seconds.
# Time taken html5lib:  0.1049506664276123 seconds.
# Time taken htmlparser:  0.04299759864807129 seconds.
# Time taken nosoup:  0.0528721809387207 seconds.
# Time taken lxml.text:  0.028985977172851562 seconds.
# Time taken html5lib:  0.037038564682006836 seconds.
# Time taken htmlparser:  0.3187143802642822 seconds.
# Time taken nosoup:  0.3187143802642822 seconds.
# Time taken lxml.text:  0.032011985778808594 seconds.
# Time taken html5lib:  0.0960378646850586 seconds.
# Time taken htmlparser:  0.06973862648010254 seconds.
# Time taken nosoup:  0.07219386100769043 seconds.
# Time taken lxml.text:  0.032559871673583984 seconds.
# Time taken html5lib:  0.09414005279541016 seconds.
# Time taken htmlparser:  0.03896522521972656 seconds.
# Time taken nosoup:  0.03966712951660156 seconds.
# Time taken lxml.text:  0.02809000015258789 seconds.
# Time taken html5lib:  0.060158491134643555 seconds.
# Time taken htmlparser:  0.14448976516723633 seconds.
# Time taken nosoup:  0.14606094360351562 seconds.
# Time taken lxml.text:  0.013486862182617188 seconds.
# Time taken html5lib:  0.17084836959838867 seconds.
# Time taken htmlparser:  0.11422157287597656 seconds.
# Time taken nosoup:  0.11523556709289551 seconds.
# Time taken lxml.text:  0.002899646759033203 seconds.
# Time taken html5lib:  0.18951416015625 seconds.
# Time taken htmlparser:  0.03705406188964844 seconds.
# Time taken nosoup:  0.04524111747741699 seconds.
# Time taken lxml.text:  0.031545400619506836 seconds.
# Time taken html5lib:  0.018207788467407227 seconds.
# Time taken htmlparser:  0.06434512138366699 seconds.
# Time taken nosoup:  0.06434512138366699 seconds.
# Time taken lxml.text:  0.04659390449523926 seconds.
# Time taken html5lib:  0.08533787727355957 seconds.
# Time taken htmlparser:  0.04069256782531738 seconds.
# Time taken nosoup:  0.04069256782531738 seconds.
# Time taken lxml.text:  0.11867213249206543 seconds.
# Time taken html5lib:  0.1524829864501953 seconds.
# Time taken htmlparser:  0.03798937797546387 seconds.
# Time taken nosoup:  0.03798937797546387 seconds.
# Time taken lxml.text:  0.03428769111633301 seconds.
# Time taken html5lib:  0.07757830619812012 seconds.
# Time taken htmlparser:  0.06517601013183594 seconds.
# Time taken nosoup:  0.0661630630493164 seconds.
# Time taken lxml.text:  0.012212991714477539 seconds.
# Time taken html5lib:  0.08488059043884277 seconds.
# Time taken htmlparser:  0.013369560241699219 seconds.
# Time taken nosoup:  0.013369560241699219 seconds.
# Time taken lxml.text:  0.15788817405700684 seconds.
# Time taken html5lib:  0.05201888084411621 seconds.
# Time taken htmlparser:  0.0722353458404541 seconds.
# Time taken nosoup:  0.0722353458404541 seconds.
# Time taken lxml.text:  0.11343097686767578 seconds.
# Time taken html5lib:  0.12094521522521973 seconds.
# Time taken htmlparser:  0.025988340377807617 seconds.
# Time taken nosoup:  0.04151725769042969 seconds.
# Time taken lxml.text:  0.02749347686767578 seconds.
# Time taken html5lib:  0.06490325927734375 seconds.
# Time taken htmlparser:  0.04462075233459473 seconds.
# Time taken nosoup:  0.04462075233459473 seconds.
# Time taken lxml.text:  0.02408146858215332 seconds.
# Time taken html5lib:  0.08034348487854004 seconds.
# Time taken htmlparser:  0.016614675521850586 seconds.
# Time taken nosoup:  0.01700878143310547 seconds.
# Time taken lxml.text:  0.010222196578979492 seconds.
# Time taken html5lib:  0.04482316970825195 seconds.
# Time taken htmlparser:  0.009404659271240234 seconds.
# Time taken nosoup:  0.04513883590698242 seconds.
# Time taken lxml.text:  0.09387707710266113 seconds.
# Time taken html5lib:  0.11591887474060059 seconds.
# Time taken htmlparser:  0.01177978515625 seconds.
# Time taken nosoup:  0.01177978515625 seconds.
# Time taken lxml.text:  0.0489962100982666 seconds.
# Time taken html5lib:  0.13891053199768066 seconds.
# Time taken htmlparser:  0.006131172180175781 seconds.
# Time taken nosoup:  0.03955435752868652 seconds.
# Time taken lxml.text:  0.027582168579101562 seconds.
# Time taken html5lib:  0.07634210586547852 seconds.
# Time taken htmlparser:  0.07438230514526367 seconds.
# Time taken nosoup:  0.07662606239318848 seconds.
# Time taken lxml.text:  0.031002521514892578 seconds.
# Time taken html5lib:  0.01914381980895996 seconds.
# Time taken htmlparser:  0.391711950302124 seconds.
# Time taken nosoup:  0.3928799629211426 seconds.
# Time taken lxml.text:  0.016606807708740234 seconds.
# Time taken html5lib:  0.009385347366333008 seconds.
# Time taken htmlparser:  0.17367911338806152 seconds.
# Time taken nosoup:  0.17367911338806152 seconds.
# Time taken lxml.text:  0.049310922622680664 seconds.
# Time taken html5lib:  0.07509708404541016 seconds.
# Time taken htmlparser:  0.27710580825805664 seconds.
# Time taken nosoup:  0.27710580825805664 seconds.
# Time taken lxml.text:  0.012918472290039062 seconds.
# Time taken html5lib:  0.15902280807495117 seconds.
# Time taken htmlparser:  0.11896443367004395 seconds.
# Time taken nosoup:  0.12595009803771973 seconds.
# Time taken lxml.text:  0.032230377197265625 seconds.
# Time taken html5lib:  0.15169572830200195 seconds.
# Time taken htmlparser:  0.0 seconds.
# Time taken nosoup:  0.0 seconds.
# Time taken lxml.text:  0.09078192710876465 seconds.
# Time taken html5lib:  0.29399943351745605 seconds.
# Time taken htmlparser:  0.026833295822143555 seconds.
# Time taken nosoup:  0.026833295822143555 seconds.
# Time taken lxml.text:  0.0 seconds.
# Time taken html5lib:  0.10520291328430176 seconds.
# Time taken htmlparser:  0.10116076469421387 seconds.
# Time taken nosoup:  0.11159968376159668 seconds.
# Time taken lxml.text:  0.01081085205078125 seconds.
# Time taken html5lib:  0.1497666835784912 seconds.
# Time taken htmlparser:  0.03798508644104004 seconds.
# Time taken nosoup:  0.05224299430847168 seconds.
# Time taken lxml.text:  0.03381085395812988 seconds.
# Time taken html5lib:  0.2500886917114258 seconds.
# Time taken htmlparser:  0.03967738151550293 seconds.
# Time taken nosoup:  0.03967738151550293 seconds.
# Time taken lxml.text:  0.026357412338256836 seconds.
# Time taken html5lib:  0.03530001640319824 seconds.
# Time taken htmlparser:  0.04294133186340332 seconds.
# Time taken nosoup:  0.04294133186340332 seconds.
# Time taken lxml.text:  0.03316831588745117 seconds.
# Time taken html5lib:  0.10400128364562988 seconds.
# Time taken htmlparser:  0.037390708923339844 seconds.
# Time taken nosoup:  0.037390708923339844 seconds.
# Time taken lxml.text:  0.04883289337158203 seconds.
# Time taken html5lib:  0.0587916374206543 seconds.
# Time taken htmlparser:  0.11214065551757812 seconds.
# Time taken nosoup:  0.11725425720214844 seconds.
# Time taken lxml.text:  0.12885475158691406 seconds.
# Time taken html5lib:  0.09086990356445312 seconds.
# Time taken htmlparser:  0.037218570709228516 seconds.
# Time taken nosoup:  0.037218570709228516 seconds.
# Time taken lxml.text:  0.3524305820465088 seconds.
# Time taken html5lib:  0.12246990203857422 seconds.
# Time taken htmlparser:  0.02388906478881836 seconds.
# Time taken nosoup:  0.0529630184173584 seconds.
# Time taken lxml.text:  0.05249285697937012 seconds.
# Time taken html5lib:  0.0959024429321289 seconds.
# Time taken htmlparser:  0.04355311393737793 seconds.
# Time taken nosoup:  0.04355311393737793 seconds.
# Time taken lxml.text:  0.04481053352355957 seconds.
# Time taken html5lib:  0.07616448402404785 seconds.
# Time taken htmlparser:  0.04084610939025879 seconds.
# Time taken nosoup:  0.04111003875732422 seconds.
# Time taken lxml.text:  0.10533905029296875 seconds.
# Time taken html5lib:  0.06564974784851074 seconds.
# Time taken htmlparser:  0.08797240257263184 seconds.
# Time taken nosoup:  0.08797240257263184 seconds.
# Time taken lxml.text:  0.029242515563964844 seconds.
# Time taken html5lib:  0.050609588623046875 seconds.
# Time taken htmlparser:  0.022320985794067383 seconds.
# Time taken nosoup:  0.022320985794067383 seconds.
# Time taken lxml.text:  0.03438758850097656 seconds.
# Time taken html5lib:  0.06670475006103516 seconds.
# Time taken htmlparser:  0.09467315673828125 seconds.
# Time taken nosoup:  0.09666275978088379 seconds.
# Time taken lxml.text:  0.025981903076171875 seconds.
# Time taken html5lib:  0.10764145851135254 seconds.
# Time taken htmlparser:  0.11633062362670898 seconds.
# Time taken nosoup:  0.1173851490020752 seconds.
# Time taken lxml.text:  0.005972862243652344 seconds.
# Time taken html5lib:  0.03200888633728027 seconds.
# Time taken htmlparser:  0.1010134220123291 seconds.
# Time taken nosoup:  0.10624861717224121 seconds.
# Time taken lxml.text:  0.02965831756591797 seconds.
# Time taken html5lib:  0.09007859230041504 seconds.
# Time taken htmlparser:  0.01611471176147461 seconds.
# Time taken nosoup:  0.04033493995666504 seconds.
# Time taken lxml.text:  0.03020477294921875 seconds.
# Time taken html5lib:  0.061397552490234375 seconds.
# Time taken htmlparser:  0.1242225170135498 seconds.
# Time taken nosoup:  0.1242225170135498 seconds.
# Time taken lxml.text:  0.011981487274169922 seconds.
# Time taken html5lib:  0.11715865135192871 seconds.
# Time taken htmlparser:  0.11719822883605957 seconds.
# Time taken nosoup:  0.11719822883605957 seconds.
# Time taken lxml.text:  0.0 seconds.
# Time taken html5lib:  0.16449952125549316 seconds.
# Time taken htmlparser:  0.03721809387207031 seconds.
# Time taken nosoup:  0.03836655616760254 seconds.
# Time taken lxml.text:  0.000820159912109375 seconds.
# Time taken html5lib:  0.15894055366516113 seconds.
# Time taken htmlparser:  0.04250311851501465 seconds.
# Time taken nosoup:  0.04400920867919922 seconds.
# Time taken lxml.text:  0.011127710342407227 seconds.
# Time taken html5lib:  0.07871723175048828 seconds.
# Time taken htmlparser:  0.031145572662353516 seconds.
# Time taken nosoup:  0.031145572662353516 seconds.
# Time taken lxml.text:  0.16314101219177246 seconds.
# Time taken html5lib:  0.20287227630615234 seconds.
# Time taken htmlparser:  0.0582890510559082 seconds.
# Time taken nosoup:  0.0582890510559082 seconds.
# Time taken lxml.text:  0.09708380699157715 seconds.
# Time taken html5lib:  0.17296814918518066 seconds.
# Time taken htmlparser:  0.10117244720458984 seconds.
# Time taken nosoup:  0.10117244720458984 seconds.
# Time taken lxml.text:  0.03296232223510742 seconds.
# Time taken html5lib:  0.179551362991333 seconds.
# Time taken htmlparser:  0.03993940353393555 seconds.
# Time taken nosoup:  0.03993940353393555 seconds.
# Time taken lxml.text:  0.023917436599731445 seconds.
# Time taken html5lib:  0.05931806564331055 seconds.
# Time taken htmlparser:  0.06587052345275879 seconds.
# Time taken nosoup:  0.06696152687072754 seconds.
# Time taken lxml.text:  0.26480865478515625 seconds.
# Time taken html5lib:  0.08699250221252441 seconds.
# Time taken htmlparser:  0.0 seconds.
# Time taken nosoup:  0.0 seconds.
# Time taken lxml.text:  0.0 seconds.
# Time taken html5lib:  0.13100004196166992 seconds.
# Time taken htmlparser:  0.04015469551086426 seconds.
# Time taken nosoup:  0.04015469551086426 seconds.
# Time taken lxml.text:  0.029056072235107422 seconds.
# Time taken html5lib:  0.08988451957702637 seconds.
# Time taken htmlparser:  0.06882095336914062 seconds.
# Time taken nosoup:  0.07034111022949219 seconds.
# Time taken lxml.text:  0.031792640686035156 seconds.
# Time taken html5lib:  0.07851219177246094 seconds.
# Time taken htmlparser:  0.0439145565032959 seconds.
# Time taken nosoup:  0.054367780685424805 seconds.
# Time taken lxml.text:  0.17869997024536133 seconds.
# Time taken html5lib:  0.0894477367401123 seconds.
# Time taken htmlparser:  0.02452254295349121 seconds.
# Time taken nosoup:  0.024672508239746094 seconds.
# Time taken lxml.text:  0.012255430221557617 seconds.
# Time taken html5lib:  0.035910606384277344 seconds.
# Time taken htmlparser:  0.017058610916137695 seconds.
# Time taken nosoup:  0.017058610916137695 seconds.
# Time taken lxml.text:  0.010920047760009766 seconds.
# Time taken html5lib:  0.04586529731750488 seconds.
# Time taken htmlparser:  0.17398810386657715 seconds.
# Time taken nosoup:  0.17398810386657715 seconds.
# Time taken lxml.text:  0.0564112663269043 seconds.
# Time taken html5lib:  0.15817689895629883 seconds.
# Time taken htmlparser:  0.13840079307556152 seconds.
# Time taken nosoup:  0.1395728588104248 seconds.
# Time taken lxml.text:  0.036975860595703125 seconds.
# Time taken html5lib:  0.09896230697631836 seconds.
# Time taken htmlparser:  0.07275748252868652 seconds.
# Time taken nosoup:  0.07369828224182129 seconds.
# Time taken lxml.text:  0.029297590255737305 seconds.
# Time taken html5lib:  0.12099146842956543 seconds.
# Time taken htmlparser:  0.04667305946350098 seconds.
# Time taken nosoup:  0.04784727096557617 seconds.
# Time taken lxml.text:  0.030986785888671875 seconds.
# Time taken html5lib:  0.0841054916381836 seconds.
# Time taken htmlparser:  0.034088134765625 seconds.
# Time taken nosoup:  0.035685062408447266 seconds.
# Time taken lxml.text:  0.03112339973449707 seconds.
# Time taken html5lib:  0.07802915573120117 seconds.
# Time taken htmlparser:  0.11633062362670898 seconds.
# Time taken nosoup:  0.1291346549987793 seconds.
# Time taken lxml.text:  0.062134742736816406 seconds.
# Time taken html5lib:  0.09079504013061523 seconds.
# Time taken htmlparser:  0.049082040786743164 seconds.
# Time taken nosoup:  0.049976348876953125 seconds.
# Time taken lxml.text:  0.030225515365600586 seconds.
# Time taken html5lib:  0.07874107360839844 seconds.
# Time taken htmlparser:  0.0410001277923584 seconds.
# Time taken nosoup:  0.04487204551696777 seconds.
# Time taken lxml.text:  0.06438088417053223 seconds.
# Time taken html5lib:  0.09459352493286133 seconds.
# Time taken htmlparser:  0.043535470962524414 seconds.
# Time taken nosoup:  0.04457426071166992 seconds.
# Time taken lxml.text:  0.028051137924194336 seconds.
# Time taken html5lib:  0.17691993713378906 seconds.
# Time taken htmlparser:  0.03089618682861328 seconds.
# Time taken nosoup:  0.03089618682861328 seconds.
# Time taken lxml.text:  0.046875953674316406 seconds.
# Time taken html5lib:  0.09257221221923828 seconds.
# Time taken htmlparser:  0.049724578857421875 seconds.
# Time taken nosoup:  0.05070924758911133 seconds.
# Time taken lxml.text:  0.027923107147216797 seconds.
# Time taken html5lib:  0.05684709548950195 seconds.
# Time taken htmlparser:  0.06165480613708496 seconds.
# Time taken nosoup:  0.07615470886230469 seconds.
# Time taken lxml.text:  0.029079914093017578 seconds.
# Time taken html5lib:  0.07401156425476074 seconds.
# Time taken htmlparser:  0.045433998107910156 seconds.
# Time taken nosoup:  0.045433998107910156 seconds.
# Time taken lxml.text:  0.04526400566101074 seconds.
# Time taken html5lib:  0.18910837173461914 seconds.
# Time taken htmlparser:  0.0500640869140625 seconds.
# Time taken nosoup:  0.05092024803161621 seconds.
# Time taken lxml.text:  0.04392814636230469 seconds.
# Time taken html5lib:  0.08755803108215332 seconds.
# Time taken htmlparser:  0.035067081451416016 seconds.
# Time taken nosoup:  0.035067081451416016 seconds.
# Time taken lxml.text:  0.03918766975402832 seconds.
# Time taken html5lib:  0.08276963233947754 seconds.
# Time taken htmlparser:  0.03492093086242676 seconds.
# Time taken nosoup:  0.03492093086242676 seconds.
# Time taken lxml.text:  0.0 seconds.
# Time taken html5lib:  0.10882449150085449 seconds.
# Time taken htmlparser:  0.041405439376831055 seconds.
# Time taken nosoup:  0.04236245155334473 seconds.
# Time taken lxml.text:  0.11255621910095215 seconds.
# Time taken html5lib:  0.08455777168273926 seconds.
# Time taken htmlparser:  0.0378565788269043 seconds.
# Time taken nosoup:  0.04083061218261719 seconds.
# Time taken lxml.text:  0.0186309814453125 seconds.
# Time taken html5lib:  0.10938191413879395 seconds.
# Time taken htmlparser:  0.046294450759887695 seconds.
# Time taken nosoup:  0.04900765419006348 seconds.
# Time taken lxml.text:  0.029249906539916992 seconds.
# Time taken html5lib:  0.07474422454833984 seconds.
# Time taken htmlparser:  0.06263208389282227 seconds.
# Time taken nosoup:  0.06541037559509277 seconds.
# Time taken lxml.text:  0.027648448944091797 seconds.
# Time taken html5lib:  0.03152871131896973 seconds.
# Time taken htmlparser:  0.260648250579834 seconds.
# Time taken nosoup:  0.2616453170776367 seconds.
# Time taken lxml.text:  0.006837129592895508 seconds.
# Time taken html5lib:  0.11410284042358398 seconds.
# Time taken htmlparser:  0.07256460189819336 seconds.
# Time taken nosoup:  7.650083303451538 seconds.
# Time taken lxml:  5.173186540603638 seconds.
# Time taken html5lib:  10.10669732093811 seconds.
# Time taken htmlparser:  6.768188953399658 seconds.

# %%
article = requests.get(
            url = url,
            cookies = {'over18': 'yes'}  # ptt18歲的認證
        )
soup = BeautifulSoup(article.text,'lxml')
r_ent = soup.select('div.r-ent')[0].text
a_url = soup.select('div.title > a')[0]['href']
a_title = soup.select('div.title')[0].text
print(a_title)
a_author = soup.select('div.author')[0].text
print(a_author)
a_date = soup.select('div.date')[0].text
print(a_date)
print('https://www.ptt.cc/'+a_url)
# Out:
#
# 				(本文已被刪除) [Flitz]
#
#
# -
#  5/10
# https://www.ptt.cc//bbs/Beauty/M.1683702297.A.A2D.html
